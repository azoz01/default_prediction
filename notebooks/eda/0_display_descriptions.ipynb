# %%
import os
os.chdir("../..")

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_rows', 200)

# %%
descriptions = pd.read_csv("resources/data/raw/data_description.csv")

# %%
descriptions.loc[descriptions["LoanStatNew"] == "application_type"]
# Out:
#         LoanStatNew  \
# 5  application_type
#
#                                                                                             Description
# 5  Indicates whether the loan is an individual application or a joint application with two co-borrowers

# %%
descriptions
# Out:
#                     LoanStatNew  \
# 0                acc_now_delinq
# 1                    addr_state
# 2                      all_util
# 3                    annual_inc
# 4              annual_inc_joint
# 5              application_type
# 6       collection_recovery_fee
# 7    collections_12_mths_ex_med
# 8                   delinq_2yrs
# 9                          desc
# 10                          dti
# 11                    dti_joint
# 12             earliest_cr_line
# 13                   emp_length
# 14                    emp_title
# 15                  funded_amnt
# 16              funded_amnt_inv
# 17                        grade
# 18               home_ownership
# 19                           id
# 20                      il_util
# 21          initial_list_status
# 22                       inq_fi
# 23                 inq_last_12m
# 24               inq_last_6mths
# 25                  installment
# 26                     int_rate
# 27                      issue_d
# ...
